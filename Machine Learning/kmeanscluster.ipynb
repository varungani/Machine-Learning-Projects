# %%
import numpy as np
import os
import tensorflow as tf

# %%
import sklearn

# %%
from sklearn.datasets import make_blobs

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
x,y=make_blobs(centers=3,random_state=42)

# %%
sns.scatterplot(x=x[0:,0] ,y=x[0:,1],hue =y)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=5)

# %%
model.fit(x)
# Out:
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5)

# %%
y_gen=model.labels_

# %%
sns.scatterplot(x=x[:,0],y=x[:,1],hue=y_gen)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=x[:,0],y=x[:,1],hue=y_gen)
for center in model.cluster_centers_:
    plt.scatter(x=center[0],y=center[1],s=60)

# %%
import random

# %%
class clusters:
    def __inti__(self,center):
        self.center=center
        self.point=[]
        
     
    def
    






class customkmeans:
    def __init__(self,n_clusters=3):
        self.n_clusters=n_clusters
    
    def fit(self,x):
